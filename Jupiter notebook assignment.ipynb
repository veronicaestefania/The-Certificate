# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Veronica Andrade**
#
# Molecular Biologist

# %% [markdown]
# *I am interested in data science because I will be able to expand my knowledge in data interpretation*. *I am also interested in data science because I'd like to explore statistical models*.

# %% [markdown]
# ### Multiplication

# %%
(89*235)
# Out:
# 20915

# %% [markdown]
# |**Color**|**Size**|**Product**|
# | ------| ---- | ----- |
# | Yellow | M | Shoes |
# | Red | 40 | Dress |
# | Black | 36 | Belt |
#
#
# ![Silly Ostrish!](https://i.insider.com/61dcd4a54ede320018b6ece2?width=1000&format=jpeg&auto=webp)
#
#
# 1. Alex
# 2. Veronica
# 3. Alejandra
# 4. Nicolas
# 5. Francesco
#
#
# My favorite youtube chanel [Kurzgesagt](https://www.youtube.com/c/inanutshell)
